# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# !pip install fastai --upgrade
# Out:
# Requirement already up-to-date: fastai in /usr/local/lib/python3.6/dist-packages (2.2.5)
# ...

# %%
from fastai.data.all import *
from fastai.vision.all import *

# %%
bs = 8 # Batch size

# %%
# !unzip -uq "/content/drive/MyDrive/Dataset" -d "/content/sample_data/" # Unzipping training set

# %%
path = Path('/content/drive/MyDrive/Dataset')

# %%
dls = ImageDataLoaders.from_folder(path, valid_pct=0.2, item_tfms=Resize(224),bs=8)

# %%
dls.valid_ds.items[:3]

# %%
dls.show_batch()

# %%
learn = cnn_learner(dls, models.resnet34, metrics=error_rate) # Initializing CNN
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.model # RESNET-34 CNN architecture
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
learn.fit_one_cycle(40) # 4 epochs
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.101272</td>
#       <td>0.106373</td>
#       <td>0.076923</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.181313</td>
#       <td>0.115962</td>
#       <td>0.076923</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.233489</td>
#       <td>0.121171</td>
#       <td>0.076923</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.275856</td>
#       <td>0.110170</td>
#       <td>0.076923</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.222774</td>
#       <td>0.155315</td>
#       <td>0.076923</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fit_one_cycle(20, 3e-3)
learn.unfreeze()
learn.fit_one_cycle(10, lr_max=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.634666</td>
#       <td>1.261595</td>
#       <td>0.615385</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.345188</td>
#       <td>0.275577</td>
#       <td>0.076923</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.883661</td>
#       <td>0.048892</td>
#       <td>0.000000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.706191</td>
#       <td>0.037753</td>
#       <td>0.000000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.590636</td>
#       <td>0.109279</td>
#       <td>0.076923</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.recorder.plot_loss()

# %%
interp = ClassificationInterpretation.from_learner(learn) # Initializing interpreter

losses,idxs = interp.top_losses() # Getting losses and class id's

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
learn.model_dir='/content/'
learn.save('stage-1') # saving model
learn.export('stage-1.pkl') # exports the model

# %%
learn1 = learn.load('/content/drive/MyDrive/stage-1')

# %%
model  = learn1.model
torch.save(model.state_dict(), "/content/drive/MyDrive/alpha")
